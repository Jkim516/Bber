# %%
import requests
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import folium
from folium.plugins import MiniMap
from time import time
import pickle

# %% [markdown]
# Scrap live station status data in https://bikeshare.metro.net/stations/json/

# %%
def get_live_station(url):
    
    response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    stations = response.json()
    
    output = []
    
    for station in stations['features']:
        dict_keys = ['kioskId', 'bikesAvailable', 'docksAvailable', 'name', 'latitude', 'longitude']
        data = {k : station['properties'][k] for k in dict_keys}
        data['time'] = pd.to_datetime('today')
        output.append(data)

    return pd.DataFrame(output)

# %%
live_station_df = get_live_station("https://bikeshare.metro.net/stations/json/")
live_station_df.head()
# Out:
#    bikesAvailable  docksAvailable  kioskId  latitude  longitude  \
# 0              23               3     3005  34.04850 -118.25854
# 1              15               9     3006  34.04554 -118.25667
# 2               6              14     3007  34.05048 -118.25459
# 3               9               6     3008  34.04661 -118.26273
# 4               8              14     3010  34.03705 -118.25487
#
#              name                       time
# 0    7th & Flower 2019-10-02 08:29:29.429393
# 1     Olive & 8th 2019-10-02 08:29:29.432897
# 2     5th & Grand 2019-10-02 08:29:29.433033
# 3  Figueroa & 9th 2019-10-02 08:29:29.433127
# 4    11th & Maple 2019-10-02 08:29:29.433230

# %%
# change time featur into str and take first 10 character.
# live_station_df.time = live_station_df.time.astype(str)
# live_station_df.time = live_station_df.time.str[:10]

# %% [markdown]
# Remove nano-seconds in time feature

# %%
live_station_df['time'] = live_station_df['time'].astype('datetime64[s]')

# %%
# convert unix timestamp to Y/M/D %H/%M/%S format
# live_station_df['time'] = pd.to_datetime(live_station_df['time'], unit='s')

# %%
# change name of time feature to ds and set it to index
# replace minutes and seconds to 0 
live_station_df.rename(columns={'time':'ds'}, inplace=True)
live_station_df.set_index('ds', inplace=True)
live_station_df.index = live_station_df.index.map(lambda x: x.replace(second=0))
live_station_df.index = live_station_df.index.map(lambda x: x.replace(minute=0))

# %%
live_station_df.kioskId = live_station_df.kioskId.astype(str)

# %%
live_station_df.head()
# Out:
#                      bikesAvailable  docksAvailable kioskId  latitude  \
# ds
# 2019-10-02 08:00:00              23               3    3005  34.04850
# 2019-10-02 08:00:00              15               9    3006  34.04554
# 2019-10-02 08:00:00               6              14    3007  34.05048
# 2019-10-02 08:00:00               9               6    3008  34.04661
# 2019-10-02 08:00:00               8              14    3010  34.03705
#
#                      longitude            name
# ds
# 2019-10-02 08:00:00 -118.25854    7th & Flower
# 2019-10-02 08:00:00 -118.25667     Olive & 8th
# 2019-10-02 08:00:00 -118.25459     5th & Grand
# 2019-10-02 08:00:00 -118.26273  Figueroa & 9th
# 2019-10-02 08:00:00 -118.25487    11th & Maple

# %% [markdown]
# ### Create new column that concatenated with ds and kioskid to merge it with station_pred_df1

# %%
live_station_df.reset_index(inplace=True)

# %%
live_station_df['id'] = live_station_df.ds.astype(str) + '-' + live_station_df.kioskId
live_station_df.head()
# Out:
#                    ds  bikesAvailable  docksAvailable kioskId  latitude  \
# 0 2019-10-02 08:00:00              23               3    3005  34.04850
# 1 2019-10-02 08:00:00              15               9    3006  34.04554
# 2 2019-10-02 08:00:00               6              14    3007  34.05048
# 3 2019-10-02 08:00:00               9               6    3008  34.04661
# 4 2019-10-02 08:00:00               8              14    3010  34.03705
#
#    longitude            name                        id
# 0 -118.25854    7th & Flower  2019-10-02 08:00:00-3005
# 1 -118.25667     Olive & 8th  2019-10-02 08:00:00-3006
# 2 -118.25459     5th & Grand  2019-10-02 08:00:00-3007
# 3 -118.26273  Figueroa & 9th  2019-10-02 08:00:00-3008
# 4 -118.25487    11th & Maple  2019-10-02 08:00:00-3010

# %% [markdown]
# ## Import forecasted station_pred_df1 that stored as a pickle

# %%
with open('station_pred_df1.pickle', 'rb') as f:
    station_pred_df1 = pickle.load(f)

station_pred_df1.head()
# Out:
#   station                  ds     y_hat
# 0  3047.0 2019-09-24 13:00:00  0.439309
# 1  3047.0 2019-09-24 14:00:00  0.432759
# 2  3047.0 2019-09-24 15:00:00  0.434784
# 3  3047.0 2019-09-24 16:00:00  0.498354
# 4  3047.0 2019-09-24 17:00:00  0.608555

# %%
station_pred_df1.tail()
# Out:
#       station                  ds     y_hat
# 17995  3078.0 2019-10-06 18:00:00  0.408277
# 17996  3078.0 2019-10-06 19:00:00  0.371387
# 17997  3078.0 2019-10-06 20:00:00  0.326630
# 17998  3078.0 2019-10-06 21:00:00  0.282961
# 17999  3078.0 2019-10-06 22:00:00  0.251276

# %%
# Take first 4 character in station feature
station_pred_df1.station = station_pred_df1.station.str[:4]

# %% [markdown]
# Create

# %%
station_pred_df1['id'] = station_pred_df1.ds.astype(str) + '-' + station_pred_df1.station

# %%
station_pred_df1.tail()
# Out:
#       station                  ds     y_hat                        id
# 17995    3078 2019-10-06 18:00:00  0.408277  2019-10-06 18:00:00-3078
# 17996    3078 2019-10-06 19:00:00  0.371387  2019-10-06 19:00:00-3078
# 17997    3078 2019-10-06 20:00:00  0.326630  2019-10-06 20:00:00-3078
# 17998    3078 2019-10-06 21:00:00  0.282961  2019-10-06 21:00:00-3078
# 17999    3078 2019-10-06 22:00:00  0.251276  2019-10-06 22:00:00-3078

# %%
station_pred_df1.set_index('ds', inplace=True)

# %%
merge_live_pred_df = station_pred_df1.merge(live_station_df, on='id')
merge_live_pred_df.head()
# Out:
#   station     y_hat                        id                  ds  \
# 0    3047  0.422070  2019-10-02 08:00:00-3047 2019-10-02 08:00:00
# 1    3005  1.836403  2019-10-02 08:00:00-3005 2019-10-02 08:00:00
# 2    3023  0.261683  2019-10-02 08:00:00-3023 2019-10-02 08:00:00
# 3    3051  0.339144  2019-10-02 08:00:00-3051 2019-10-02 08:00:00
# 4    3007  0.382885  2019-10-02 08:00:00-3007 2019-10-02 08:00:00
#
#    bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0              18              18    3047  34.03998 -118.26640
# 1              23               3    3005  34.04850 -118.25854
# 2              12              10    3023  34.05091 -118.24097
# 3               7               9    3051  34.04542 -118.25352
# 4               6              14    3007  34.05048 -118.25459
#
#                     name
# 0          Pico & Flower
# 1           7th & Flower
# 2  1st & Judge John Aiso
# 3         7th & Broadway
# 4            5th & Grand

# %%
merge_live_pred_df.head()
# Out:
#   station     y_hat                        id                  ds  \
# 0    3047  0.422070  2019-10-02 08:00:00-3047 2019-10-02 08:00:00
# 1    3005  1.836403  2019-10-02 08:00:00-3005 2019-10-02 08:00:00
# 2    3023  0.261683  2019-10-02 08:00:00-3023 2019-10-02 08:00:00
# 3    3051  0.339144  2019-10-02 08:00:00-3051 2019-10-02 08:00:00
# 4    3007  0.382885  2019-10-02 08:00:00-3007 2019-10-02 08:00:00
#
#    bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0              18              18    3047  34.03998 -118.26640
# 1              23               3    3005  34.04850 -118.25854
# 2              12              10    3023  34.05091 -118.24097
# 3               7               9    3051  34.04542 -118.25352
# 4               6              14    3007  34.05048 -118.25459
#
#                     name
# 0          Pico & Flower
# 1           7th & Flower
# 2  1st & Judge John Aiso
# 3         7th & Broadway
# 4            5th & Grand

# %%
def normalize_demand_number(record):
    if record['y_hat'] >= 4.4:
        return round(record['y_hat']) * 3
    elif record['y_hat'] >= 4:
        return round(record['y_hat']) * 2
    elif record['y_hat'] >= 3:
        return round(record['y_hat']) * 2
    elif record['y_hat'] >= 1:
        return round(record['y_hat']) * 3
    elif record['y_hat'] >= 0.7:
        return round(record['y_hat']) * 2
    elif record['y_hat'] >= 0.4:
        return 1
    else:
        return 0

# %%
merge_live_pred_df['demand'] = merge_live_pred_df.apply(normalize_demand_number, axis=1)
merge_live_pred_df
# Out:
#    station     y_hat                        id                  ds  \
# 0     3047  0.422070  2019-10-02 08:00:00-3047 2019-10-02 08:00:00
# 1     3005  1.836403  2019-10-02 08:00:00-3005 2019-10-02 08:00:00
# 2     3023  0.261683  2019-10-02 08:00:00-3023 2019-10-02 08:00:00
# 3     3051  0.339144  2019-10-02 08:00:00-3051 2019-10-02 08:00:00
# 4     3007  0.382885  2019-10-02 08:00:00-3007 2019-10-02 08:00:00
# 5     3075  0.433229  2019-10-02 08:00:00-3075 2019-10-02 08:00:00
# 6     3066  0.814117  2019-10-02 08:00:00-3066 2019-10-02 08:00:00
# 7     3082  1.016542  2019-10-02 08:00:00-3082 2019-10-02 08:00:00
# 8     3064  0.337102  2019-10-02 08:00:00-3064 2019-10-02 08:00:00
# 9     3052  0.384230  2019-10-02 08:00:00-3052 2019-10-02 08:00:00
# 10    3029  0.319877  2019-10-02 08:00:00-3029 2019-10-02 08:00:00
# 11    3006  0.866437  2019-10-02 08:00:00-3006 2019-10-02 08:00:00
# 12    3018  0.517199  2019-10-02 08:00:00-3018 2019-10-02 08:00:00
# 13    3035  0.470354  2019-10-02 08:00:00-3035 2019-10-02 08:00:00
# 14    3032  0.321514  2019-10-02 08:00:00-3032 2019-10-02 08:00:00
# 15    3030  1.605959  2019-10-02 08:00:00-3030 2019-10-02 08:00:00
# 16    3074  0.611920  2019-10-02 08:00:00-3074 2019-10-02 08:00:00
# 17    3022  0.877824  2019-10-02 08:00:00-3022 2019-10-02 08:00:00
# 18    3069  0.167594  2019-10-02 08:00:00-3069 2019-10-02 08:00:00
# 19    3042  2.030617  2019-10-02 08:00:00-3042 2019-10-02 08:00:00
# 20    3026  1.011810  2019-10-02 08:00:00-3026 2019-10-02 08:00:00
# 21    3054 -0.032430  2019-10-02 08:00:00-3054 2019-10-02 08:00:00
# 22    3024  0.084482  2019-10-02 08:00:00-3024 2019-10-02 08:00:00
# 23    3038  0.686213  2019-10-02 08:00:00-3038 2019-10-02 08:00:00
# 24    3037  0.124551  2019-10-02 08:00:00-3037 2019-10-02 08:00:00
# 25    3062  0.479960  2019-10-02 08:00:00-3062 2019-10-02 08:00:00
# 26    3068  0.719662  2019-10-02 08:00:00-3068 2019-10-02 08:00:00
# 27    3058  0.055795  2019-10-02 08:00:00-3058 2019-10-02 08:00:00
# 28    3067  0.955464  2019-10-02 08:00:00-3067 2019-10-02 08:00:00
# 29    3040  0.700861  2019-10-02 08:00:00-3040 2019-10-02 08:00:00
# 30    3036 -0.038273  2019-10-02 08:00:00-3036 2019-10-02 08:00:00
# 31    3056  0.151761  2019-10-02 08:00:00-3056 2019-10-02 08:00:00
# 32    3008  0.072341  2019-10-02 08:00:00-3008 2019-10-02 08:00:00
# 33    3031  1.131843  2019-10-02 08:00:00-3031 2019-10-02 08:00:00
# 34    3034  0.895563  2019-10-02 08:00:00-3034 2019-10-02 08:00:00
# 35    3063  0.279143  2019-10-02 08:00:00-3063 2019-10-02 08:00:00
# 36    3077  0.122883  2019-10-02 08:00:00-3077 2019-10-02 08:00:00
# 37    3048  0.017565  2019-10-02 08:00:00-3048 2019-10-02 08:00:00
# 38    3049  0.919574  2019-10-02 08:00:00-3049 2019-10-02 08:00:00
# 39    3016  0.388130  2019-10-02 08:00:00-3016 2019-10-02 08:00:00
# 40    3014  4.483605  2019-10-02 08:00:00-3014 2019-10-02 08:00:00
# 41    3011  0.095873  2019-10-02 08:00:00-3011 2019-10-02 08:00:00
# 42    3076  0.164003  2019-10-02 08:00:00-3076 2019-10-02 08:00:00
# 43    3033  0.253650  2019-10-02 08:00:00-3033 2019-10-02 08:00:00
# 44    3027  0.819730  2019-10-02 08:00:00-3027 2019-10-02 08:00:00
# 45    3019  0.663232  2019-10-02 08:00:00-3019 2019-10-02 08:00:00
# 46    3046  0.351482  2019-10-02 08:00:00-3046 2019-10-02 08:00:00
# 47    3010 -0.001546  2019-10-02 08:00:00-3010 2019-10-02 08:00:00
# 48    3020  0.125386  2019-10-02 08:00:00-3020 2019-10-02 08:00:00
# 49    3025  0.070506  2019-10-02 08:00:00-3025 2019-10-02 08:00:00
# 50    3028  0.358273  2019-10-02 08:00:00-3028 2019-10-02 08:00:00
# 51    3065  0.182857  2019-10-02 08:00:00-3065 2019-10-02 08:00:00
# 52    3057  0.157502  2019-10-02 08:00:00-3057 2019-10-02 08:00:00
# 53    3045  0.114418  2019-10-02 08:00:00-3045 2019-10-02 08:00:00
# 54    3081  0.105571  2019-10-02 08:00:00-3081 2019-10-02 08:00:00
# 55    3078  0.263886  2019-10-02 08:00:00-3078 2019-10-02 08:00:00
#
#     bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0               18              18    3047  34.03998 -118.26640
# 1               23               3    3005  34.04850 -118.25854
# 2               12              10    3023  34.05091 -118.24097
# 3                7               9    3051  34.04542 -118.25352
# 4                6              14    3007  34.05048 -118.25459
# 5                4              12    3075  34.04211 -118.25619
# 6                0              27    3066  34.06339 -118.23616
# 7               12              15    3082  34.04652 -118.23741
# 8                7              11    3064  34.04681 -118.25698
# 9                5              29    3052  34.05110 -118.26456
# 10              15               9    3029  34.04885 -118.24642
# 11              15               9    3006  34.04554 -118.25667
# 12              17               5    3018  34.04373 -118.26014
# 13               8              15    3035  34.04840 -118.26095
# 14              11              20    3032  34.04989 -118.25588
# 15              17              12    3030  34.05194 -118.24353
# 16              13               9    3074  34.04417 -118.26117
# 17               9              17    3022  34.04607 -118.23309
# 18              16               7    3069  34.05088 -118.24825
# 19               8              12    3042  34.04930 -118.23881
# 20              13              12    3026  34.06318 -118.24588
# 21              12               7    3054  34.03922 -118.23649
# 22               6              11    3024  34.05772 -118.24897
# 23               7              11    3038  34.04682 -118.24835
# 24               9              11    3037  34.03480 -118.23128
# 25              18               9    3062  34.04775 -118.24317
# 26               9              17    3068  34.05320 -118.25095
# 27              11              18    3058  34.03580 -118.23317
# 28               9              10    3067  34.04518 -118.25024
# 29              13              15    3040  34.05357 -118.26636
# 30               8              10    3036  34.03919 -118.23253
# 31               5              15    3056  34.03746 -118.26538
# 32               9               6    3008  34.04661 -118.26273
# 33              10              13    3031  34.04470 -118.25244
# 34              12              17    3034  34.04206 -118.26338
# 35              16               5    3063  34.04804 -118.25374
# 36              12               9    3077  34.03987 -118.25004
# 37               9               7    3048  34.04169 -118.23535
# 38              10              24    3049  34.05697 -118.25359
# 39              11              18    3016  34.05290 -118.24156
# 40               5              24    3014  34.05661 -118.23721
# 41               9              10    3011  34.04113 -118.26798
# 42              13              15    3076  34.04060 -118.25384
# 43               9              12    3033  34.04099 -118.25580
# 44               6              21    3027  34.04998 -118.24716
# 45               8              11    3019  34.03861 -118.26086
# 46               8               9    3046  34.05287 -118.24749
# 47               8              14    3010  34.03705 -118.25487
# 48              10              11    3020  34.03105 -118.26709
# 49               9              12    3025  34.03286 -118.26808
# 50               9              14    3028  34.05832 -118.24609
# 51              11              10    3065  34.06056 -118.23833
# 52               7              13    3057  34.03568 -118.27081
# 53               7               7    3045  34.02851 -118.25667
# 54              10               9    3081  34.03189 -118.25018
# 55              17              16    3078  34.06428 -118.23894
#
#                          name  demand
# 0               Pico & Flower       1
# 1                7th & Flower       6
# 2       1st & Judge John Aiso       0
# 3              7th & Broadway       0
# 4                 5th & Grand       0
# 5              Broadway & 9th       1
# 6            Spring & College       2
# 7             Traction & Rose       3
# 8                 Grand & 7th       0
# 9                 7th & Bixel       0
# 10                 Main & 4th       0
# 11                Olive & 8th       2
# 12            Grand & Olympic       1
# 13             Figueroa & 8th       1
# 14                 Hope & 6th       0
# 15                 Main & 1st       6
# 16             Hope & Olympic       1
# 17             3rd & Santa Fe       2
# 18             Broadway & 3rd       0
# 19              1st & Central       6
# 20    Figueroa & Cesar Chavez       3
# 21    Factory Place & Alameda       0
# 22                 Hope & 1st       0
# 23                 Main & 5th       1
# 24             Imperial & 7th       0
# 25            3rd & San Pedro       1
# 26                Grand & 3rd       2
# 27   Industrial St & Mateo St       0
# 28                 Main & 6th       2
# 29          Wilshire & Witmer       2
# 30       Willow St & Mateo St       0
# 31               Grand & 14th       0
# 32             Figueroa & 9th       0
# 33               7th & Spring       3
# 34                Hope & 11th       2
# 35                Olive & 5th       0
# 36                 8th & Wall       0
# 37               5th & Hewitt       0
# 38             2nd & Figueroa       2
# 39       Los Angeles & Temple       0
# 40  Union Station West Portal      12
# 41            Figueroa & Pico       0
# 42          9th & Los Angeles       0
# 43                 Main & 9th       0
# 44               Spring & 3rd       2
# 45                12th & Hill       1
# 46                 2nd & Hill       0
# 47               11th & Maple       0
# 48          Hill & Washington       0
# 49         Grand & Washington       0
# 50             Grand & Temple       0
# 51             New High & Ord       0
# 52            18th & Figueroa       0
# 53           18th & San Pedro       0
# 54            Stanford & 12th       0
# 55             Hill & College       0

# %%
with open('end_station_pred_df.pickle', 'rb') as f:
    end_station_pred_df = pickle.load(f)

end_station_pred_df.rename(columns={'y_hat': 'ys'}, inplace=True)
end_station_pred_df.head()
# Out:
#   station                  ds        ys
# 0  3047.0 2017-04-01 07:00:00  0.339388
# 1  3047.0 2017-04-01 08:00:00  0.461941
# 2  3047.0 2017-04-01 09:00:00  0.454687
# 3  3047.0 2017-04-01 10:00:00  0.350759
# 4  3047.0 2017-04-01 11:00:00  0.236763

# %%
end_station_pred_df.station = end_station_pred_df.station.str[:4]
end_station_pred_df['id'] = end_station_pred_df.ds.astype(str) + '-' + end_station_pred_df.station
end_station_pred_df.set_index('ds', inplace=True)

# %%
merge_live_pred_df = merge_live_pred_df.merge(end_station_pred_df[['id', 'ys']], on='id')

# %%
def normalize_ys_number(record):
    if record['ys'] >= 3:
        return round(record['ys']) * 2
    elif record['ys'] >= 1:
        return round(record['ys']) * 3
    elif record['ys'] >= .8:
        return round(record['ys']) * 2
    elif record['ys'] >= .5:
        return round(record['ys']) * 1
    else:
        return 0

# %%
merge_live_pred_df['surplus'] = merge_live_pred_df.apply(normalize_ys_number, axis=1)
merge_live_pred_df
# Out:
#    station     y_hat                        id                  ds  \
# 0     3047  0.422070  2019-10-02 08:00:00-3047 2019-10-02 08:00:00
# 1     3005  1.836403  2019-10-02 08:00:00-3005 2019-10-02 08:00:00
# 2     3023  0.261683  2019-10-02 08:00:00-3023 2019-10-02 08:00:00
# 3     3051  0.339144  2019-10-02 08:00:00-3051 2019-10-02 08:00:00
# 4     3007  0.382885  2019-10-02 08:00:00-3007 2019-10-02 08:00:00
# 5     3075  0.433229  2019-10-02 08:00:00-3075 2019-10-02 08:00:00
# 6     3066  0.814117  2019-10-02 08:00:00-3066 2019-10-02 08:00:00
# 7     3082  1.016542  2019-10-02 08:00:00-3082 2019-10-02 08:00:00
# 8     3064  0.337102  2019-10-02 08:00:00-3064 2019-10-02 08:00:00
# 9     3052  0.384230  2019-10-02 08:00:00-3052 2019-10-02 08:00:00
# 10    3029  0.319877  2019-10-02 08:00:00-3029 2019-10-02 08:00:00
# 11    3006  0.866437  2019-10-02 08:00:00-3006 2019-10-02 08:00:00
# 12    3018  0.517199  2019-10-02 08:00:00-3018 2019-10-02 08:00:00
# 13    3035  0.470354  2019-10-02 08:00:00-3035 2019-10-02 08:00:00
# 14    3032  0.321514  2019-10-02 08:00:00-3032 2019-10-02 08:00:00
# 15    3030  1.605959  2019-10-02 08:00:00-3030 2019-10-02 08:00:00
# 16    3074  0.611920  2019-10-02 08:00:00-3074 2019-10-02 08:00:00
# 17    3022  0.877824  2019-10-02 08:00:00-3022 2019-10-02 08:00:00
# 18    3069  0.167594  2019-10-02 08:00:00-3069 2019-10-02 08:00:00
# 19    3042  2.030617  2019-10-02 08:00:00-3042 2019-10-02 08:00:00
# 20    3026  1.011810  2019-10-02 08:00:00-3026 2019-10-02 08:00:00
# 21    3054 -0.032430  2019-10-02 08:00:00-3054 2019-10-02 08:00:00
# 22    3024  0.084482  2019-10-02 08:00:00-3024 2019-10-02 08:00:00
# 23    3038  0.686213  2019-10-02 08:00:00-3038 2019-10-02 08:00:00
# 24    3037  0.124551  2019-10-02 08:00:00-3037 2019-10-02 08:00:00
# 25    3062  0.479960  2019-10-02 08:00:00-3062 2019-10-02 08:00:00
# 26    3068  0.719662  2019-10-02 08:00:00-3068 2019-10-02 08:00:00
# 27    3058  0.055795  2019-10-02 08:00:00-3058 2019-10-02 08:00:00
# 28    3067  0.955464  2019-10-02 08:00:00-3067 2019-10-02 08:00:00
# 29    3040  0.700861  2019-10-02 08:00:00-3040 2019-10-02 08:00:00
# 30    3036 -0.038273  2019-10-02 08:00:00-3036 2019-10-02 08:00:00
# 31    3056  0.151761  2019-10-02 08:00:00-3056 2019-10-02 08:00:00
# 32    3008  0.072341  2019-10-02 08:00:00-3008 2019-10-02 08:00:00
# 33    3031  1.131843  2019-10-02 08:00:00-3031 2019-10-02 08:00:00
# 34    3034  0.895563  2019-10-02 08:00:00-3034 2019-10-02 08:00:00
# 35    3063  0.279143  2019-10-02 08:00:00-3063 2019-10-02 08:00:00
# 36    3077  0.122883  2019-10-02 08:00:00-3077 2019-10-02 08:00:00
# 37    3048  0.017565  2019-10-02 08:00:00-3048 2019-10-02 08:00:00
# 38    3049  0.919574  2019-10-02 08:00:00-3049 2019-10-02 08:00:00
# 39    3016  0.388130  2019-10-02 08:00:00-3016 2019-10-02 08:00:00
# 40    3014  4.483605  2019-10-02 08:00:00-3014 2019-10-02 08:00:00
# 41    3011  0.095873  2019-10-02 08:00:00-3011 2019-10-02 08:00:00
# 42    3076  0.164003  2019-10-02 08:00:00-3076 2019-10-02 08:00:00
# 43    3033  0.253650  2019-10-02 08:00:00-3033 2019-10-02 08:00:00
# 44    3027  0.819730  2019-10-02 08:00:00-3027 2019-10-02 08:00:00
# 45    3019  0.663232  2019-10-02 08:00:00-3019 2019-10-02 08:00:00
# 46    3046  0.351482  2019-10-02 08:00:00-3046 2019-10-02 08:00:00
# 47    3010 -0.001546  2019-10-02 08:00:00-3010 2019-10-02 08:00:00
# 48    3020  0.125386  2019-10-02 08:00:00-3020 2019-10-02 08:00:00
# 49    3025  0.070506  2019-10-02 08:00:00-3025 2019-10-02 08:00:00
# 50    3028  0.358273  2019-10-02 08:00:00-3028 2019-10-02 08:00:00
# 51    3065  0.182857  2019-10-02 08:00:00-3065 2019-10-02 08:00:00
# 52    3057  0.157502  2019-10-02 08:00:00-3057 2019-10-02 08:00:00
# 53    3045  0.114418  2019-10-02 08:00:00-3045 2019-10-02 08:00:00
# 54    3081  0.105571  2019-10-02 08:00:00-3081 2019-10-02 08:00:00
# 55    3078  0.263886  2019-10-02 08:00:00-3078 2019-10-02 08:00:00
#
#     bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0               18              18    3047  34.03998 -118.26640
# 1               23               3    3005  34.04850 -118.25854
# 2               12              10    3023  34.05091 -118.24097
# 3                7               9    3051  34.04542 -118.25352
# 4                6              14    3007  34.05048 -118.25459
# 5                4              12    3075  34.04211 -118.25619
# 6                0              27    3066  34.06339 -118.23616
# 7               12              15    3082  34.04652 -118.23741
# 8                7              11    3064  34.04681 -118.25698
# 9                5              29    3052  34.05110 -118.26456
# 10              15               9    3029  34.04885 -118.24642
# 11              15               9    3006  34.04554 -118.25667
# 12              17               5    3018  34.04373 -118.26014
# 13               8              15    3035  34.04840 -118.26095
# 14              11              20    3032  34.04989 -118.25588
# 15              17              12    3030  34.05194 -118.24353
# 16              13               9    3074  34.04417 -118.26117
# 17               9              17    3022  34.04607 -118.23309
# 18              16               7    3069  34.05088 -118.24825
# 19               8              12    3042  34.04930 -118.23881
# 20              13              12    3026  34.06318 -118.24588
# 21              12               7    3054  34.03922 -118.23649
# 22               6              11    3024  34.05772 -118.24897
# 23               7              11    3038  34.04682 -118.24835
# 24               9              11    3037  34.03480 -118.23128
# 25              18               9    3062  34.04775 -118.24317
# 26               9              17    3068  34.05320 -118.25095
# 27              11              18    3058  34.03580 -118.23317
# 28               9              10    3067  34.04518 -118.25024
# 29              13              15    3040  34.05357 -118.26636
# 30               8              10    3036  34.03919 -118.23253
# 31               5              15    3056  34.03746 -118.26538
# 32               9               6    3008  34.04661 -118.26273
# 33              10              13    3031  34.04470 -118.25244
# 34              12              17    3034  34.04206 -118.26338
# 35              16               5    3063  34.04804 -118.25374
# 36              12               9    3077  34.03987 -118.25004
# 37               9               7    3048  34.04169 -118.23535
# 38              10              24    3049  34.05697 -118.25359
# 39              11              18    3016  34.05290 -118.24156
# 40               5              24    3014  34.05661 -118.23721
# 41               9              10    3011  34.04113 -118.26798
# 42              13              15    3076  34.04060 -118.25384
# 43               9              12    3033  34.04099 -118.25580
# 44               6              21    3027  34.04998 -118.24716
# 45               8              11    3019  34.03861 -118.26086
# 46               8               9    3046  34.05287 -118.24749
# 47               8              14    3010  34.03705 -118.25487
# 48              10              11    3020  34.03105 -118.26709
# 49               9              12    3025  34.03286 -118.26808
# 50               9              14    3028  34.05832 -118.24609
# 51              11              10    3065  34.06056 -118.23833
# 52               7              13    3057  34.03568 -118.27081
# 53               7               7    3045  34.02851 -118.25667
# 54              10               9    3081  34.03189 -118.25018
# 55              17              16    3078  34.06428 -118.23894
#
#                          name  demand        ys  surplus
# 0               Pico & Flower       1  0.325964        0
# 1                7th & Flower       6  3.699468        8
# 2       1st & Judge John Aiso       0  0.318803        0
# 3              7th & Broadway       0  0.099961        0
# 4                 5th & Grand       0  1.211896        3
# 5              Broadway & 9th       1  0.430229        0
# 6            Spring & College       2  0.466051        0
# 7             Traction & Rose       3  0.223523        0
# 8                 Grand & 7th       0  0.601296        1
# 9                 7th & Bixel       0  0.299696        0
# 10                 Main & 4th       0  0.219330        0
# 11                Olive & 8th       2  0.689370        1
# 12            Grand & Olympic       1  0.436850        0
# 13             Figueroa & 8th       1  0.781118        1
# 14                 Hope & 6th       0  1.384666        3
# 15                 Main & 1st       6  4.168185        8
# 16             Hope & Olympic       1  0.280646        0
# 17             3rd & Santa Fe       2  0.524664        1
# 18             Broadway & 3rd       0  0.482691        0
# 19              1st & Central       6  0.324589        0
# 20    Figueroa & Cesar Chavez       3  0.292809        0
# 21    Factory Place & Alameda       0  0.323163        0
# 22                 Hope & 1st       0  0.125071        0
# 23                 Main & 5th       1  0.164649        0
# 24             Imperial & 7th       0  0.314015        0
# 25            3rd & San Pedro       1  0.394222        0
# 26                Grand & 3rd       2  0.631312        1
# 27   Industrial St & Mateo St       0  0.245897        0
# 28                 Main & 6th       2  0.180561        0
# 29          Wilshire & Witmer       2  0.264888        0
# 30       Willow St & Mateo St       0  0.246466        0
# 31               Grand & 14th       0  0.197987        0
# 32             Figueroa & 9th       0  0.589952        1
# 33               7th & Spring       3  0.403695        0
# 34                Hope & 11th       2  0.432381        0
# 35                Olive & 5th       0  0.953742        2
# 36                 8th & Wall       0  0.119285        0
# 37               5th & Hewitt       0  0.260761        0
# 38             2nd & Figueroa       2  0.938180        2
# 39       Los Angeles & Temple       0  0.818669        2
# 40  Union Station West Portal      12  1.473679        3
# 41            Figueroa & Pico       0  0.157723        0
# 42          9th & Los Angeles       0  0.286689        0
# 43                 Main & 9th       0  0.453661        0
# 44               Spring & 3rd       2  0.990235        2
# 45                12th & Hill       1  0.973827        2
# 46                 2nd & Hill       0  0.548926        1
# 47               11th & Maple       0  0.080159        0
# 48          Hill & Washington       0  0.228280        0
# 49         Grand & Washington       0  0.126993        0
# 50             Grand & Temple       0  0.446236        0
# 51             New High & Ord       0  0.072245        0
# 52            18th & Figueroa       0  0.024793        0
# 53           18th & San Pedro       0  0.093411        0
# 54            Stanford & 12th       0  0.571047        1
# 55             Hill & College       0  0.164530        0

# %%
def nexthour(record):
    if record['bikesAvailable'] - record['demand'] + record['surplus'] >= 0:
        return record['bikesAvailable'] - record['demand'] + record['surplus']
    else:
        return 0

# %%
merge_live_pred_df['nextHour'] = merge_live_pred_df.apply(nexthour, axis=1)
merge_live_pred_df
# Out:
#    station     y_hat                        id                  ds  \
# 0     3047  0.422070  2019-10-02 08:00:00-3047 2019-10-02 08:00:00
# 1     3005  1.836403  2019-10-02 08:00:00-3005 2019-10-02 08:00:00
# 2     3023  0.261683  2019-10-02 08:00:00-3023 2019-10-02 08:00:00
# 3     3051  0.339144  2019-10-02 08:00:00-3051 2019-10-02 08:00:00
# 4     3007  0.382885  2019-10-02 08:00:00-3007 2019-10-02 08:00:00
# 5     3075  0.433229  2019-10-02 08:00:00-3075 2019-10-02 08:00:00
# 6     3066  0.814117  2019-10-02 08:00:00-3066 2019-10-02 08:00:00
# 7     3082  1.016542  2019-10-02 08:00:00-3082 2019-10-02 08:00:00
# 8     3064  0.337102  2019-10-02 08:00:00-3064 2019-10-02 08:00:00
# 9     3052  0.384230  2019-10-02 08:00:00-3052 2019-10-02 08:00:00
# 10    3029  0.319877  2019-10-02 08:00:00-3029 2019-10-02 08:00:00
# 11    3006  0.866437  2019-10-02 08:00:00-3006 2019-10-02 08:00:00
# 12    3018  0.517199  2019-10-02 08:00:00-3018 2019-10-02 08:00:00
# 13    3035  0.470354  2019-10-02 08:00:00-3035 2019-10-02 08:00:00
# 14    3032  0.321514  2019-10-02 08:00:00-3032 2019-10-02 08:00:00
# 15    3030  1.605959  2019-10-02 08:00:00-3030 2019-10-02 08:00:00
# 16    3074  0.611920  2019-10-02 08:00:00-3074 2019-10-02 08:00:00
# 17    3022  0.877824  2019-10-02 08:00:00-3022 2019-10-02 08:00:00
# 18    3069  0.167594  2019-10-02 08:00:00-3069 2019-10-02 08:00:00
# 19    3042  2.030617  2019-10-02 08:00:00-3042 2019-10-02 08:00:00
# 20    3026  1.011810  2019-10-02 08:00:00-3026 2019-10-02 08:00:00
# 21    3054 -0.032430  2019-10-02 08:00:00-3054 2019-10-02 08:00:00
# 22    3024  0.084482  2019-10-02 08:00:00-3024 2019-10-02 08:00:00
# 23    3038  0.686213  2019-10-02 08:00:00-3038 2019-10-02 08:00:00
# 24    3037  0.124551  2019-10-02 08:00:00-3037 2019-10-02 08:00:00
# 25    3062  0.479960  2019-10-02 08:00:00-3062 2019-10-02 08:00:00
# 26    3068  0.719662  2019-10-02 08:00:00-3068 2019-10-02 08:00:00
# 27    3058  0.055795  2019-10-02 08:00:00-3058 2019-10-02 08:00:00
# 28    3067  0.955464  2019-10-02 08:00:00-3067 2019-10-02 08:00:00
# 29    3040  0.700861  2019-10-02 08:00:00-3040 2019-10-02 08:00:00
# 30    3036 -0.038273  2019-10-02 08:00:00-3036 2019-10-02 08:00:00
# 31    3056  0.151761  2019-10-02 08:00:00-3056 2019-10-02 08:00:00
# 32    3008  0.072341  2019-10-02 08:00:00-3008 2019-10-02 08:00:00
# 33    3031  1.131843  2019-10-02 08:00:00-3031 2019-10-02 08:00:00
# 34    3034  0.895563  2019-10-02 08:00:00-3034 2019-10-02 08:00:00
# 35    3063  0.279143  2019-10-02 08:00:00-3063 2019-10-02 08:00:00
# 36    3077  0.122883  2019-10-02 08:00:00-3077 2019-10-02 08:00:00
# 37    3048  0.017565  2019-10-02 08:00:00-3048 2019-10-02 08:00:00
# 38    3049  0.919574  2019-10-02 08:00:00-3049 2019-10-02 08:00:00
# 39    3016  0.388130  2019-10-02 08:00:00-3016 2019-10-02 08:00:00
# 40    3014  4.483605  2019-10-02 08:00:00-3014 2019-10-02 08:00:00
# 41    3011  0.095873  2019-10-02 08:00:00-3011 2019-10-02 08:00:00
# 42    3076  0.164003  2019-10-02 08:00:00-3076 2019-10-02 08:00:00
# 43    3033  0.253650  2019-10-02 08:00:00-3033 2019-10-02 08:00:00
# 44    3027  0.819730  2019-10-02 08:00:00-3027 2019-10-02 08:00:00
# 45    3019  0.663232  2019-10-02 08:00:00-3019 2019-10-02 08:00:00
# 46    3046  0.351482  2019-10-02 08:00:00-3046 2019-10-02 08:00:00
# 47    3010 -0.001546  2019-10-02 08:00:00-3010 2019-10-02 08:00:00
# 48    3020  0.125386  2019-10-02 08:00:00-3020 2019-10-02 08:00:00
# 49    3025  0.070506  2019-10-02 08:00:00-3025 2019-10-02 08:00:00
# 50    3028  0.358273  2019-10-02 08:00:00-3028 2019-10-02 08:00:00
# 51    3065  0.182857  2019-10-02 08:00:00-3065 2019-10-02 08:00:00
# 52    3057  0.157502  2019-10-02 08:00:00-3057 2019-10-02 08:00:00
# 53    3045  0.114418  2019-10-02 08:00:00-3045 2019-10-02 08:00:00
# 54    3081  0.105571  2019-10-02 08:00:00-3081 2019-10-02 08:00:00
# 55    3078  0.263886  2019-10-02 08:00:00-3078 2019-10-02 08:00:00
#
#     bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0               18              18    3047  34.03998 -118.26640
# 1               23               3    3005  34.04850 -118.25854
# 2               12              10    3023  34.05091 -118.24097
# 3                7               9    3051  34.04542 -118.25352
# 4                6              14    3007  34.05048 -118.25459
# 5                4              12    3075  34.04211 -118.25619
# 6                0              27    3066  34.06339 -118.23616
# 7               12              15    3082  34.04652 -118.23741
# 8                7              11    3064  34.04681 -118.25698
# 9                5              29    3052  34.05110 -118.26456
# 10              15               9    3029  34.04885 -118.24642
# 11              15               9    3006  34.04554 -118.25667
# 12              17               5    3018  34.04373 -118.26014
# 13               8              15    3035  34.04840 -118.26095
# 14              11              20    3032  34.04989 -118.25588
# 15              17              12    3030  34.05194 -118.24353
# 16              13               9    3074  34.04417 -118.26117
# 17               9              17    3022  34.04607 -118.23309
# 18              16               7    3069  34.05088 -118.24825
# 19               8              12    3042  34.04930 -118.23881
# 20              13              12    3026  34.06318 -118.24588
# 21              12               7    3054  34.03922 -118.23649
# 22               6              11    3024  34.05772 -118.24897
# 23               7              11    3038  34.04682 -118.24835
# 24               9              11    3037  34.03480 -118.23128
# 25              18               9    3062  34.04775 -118.24317
# 26               9              17    3068  34.05320 -118.25095
# 27              11              18    3058  34.03580 -118.23317
# 28               9              10    3067  34.04518 -118.25024
# 29              13              15    3040  34.05357 -118.26636
# 30               8              10    3036  34.03919 -118.23253
# 31               5              15    3056  34.03746 -118.26538
# 32               9               6    3008  34.04661 -118.26273
# 33              10              13    3031  34.04470 -118.25244
# 34              12              17    3034  34.04206 -118.26338
# 35              16               5    3063  34.04804 -118.25374
# 36              12               9    3077  34.03987 -118.25004
# 37               9               7    3048  34.04169 -118.23535
# 38              10              24    3049  34.05697 -118.25359
# 39              11              18    3016  34.05290 -118.24156
# 40               5              24    3014  34.05661 -118.23721
# 41               9              10    3011  34.04113 -118.26798
# 42              13              15    3076  34.04060 -118.25384
# 43               9              12    3033  34.04099 -118.25580
# 44               6              21    3027  34.04998 -118.24716
# 45               8              11    3019  34.03861 -118.26086
# 46               8               9    3046  34.05287 -118.24749
# 47               8              14    3010  34.03705 -118.25487
# 48              10              11    3020  34.03105 -118.26709
# 49               9              12    3025  34.03286 -118.26808
# 50               9              14    3028  34.05832 -118.24609
# 51              11              10    3065  34.06056 -118.23833
# 52               7              13    3057  34.03568 -118.27081
# 53               7               7    3045  34.02851 -118.25667
# 54              10               9    3081  34.03189 -118.25018
# 55              17              16    3078  34.06428 -118.23894
#
#                          name  demand        ys  surplus  nextHour
# 0               Pico & Flower       1  0.325964        0        17
# 1                7th & Flower       6  3.699468        8        25
# 2       1st & Judge John Aiso       0  0.318803        0        12
# 3              7th & Broadway       0  0.099961        0         7
# 4                 5th & Grand       0  1.211896        3         9
# 5              Broadway & 9th       1  0.430229        0         3
# 6            Spring & College       2  0.466051        0         0
# 7             Traction & Rose       3  0.223523        0         9
# 8                 Grand & 7th       0  0.601296        1         8
# 9                 7th & Bixel       0  0.299696        0         5
# 10                 Main & 4th       0  0.219330        0        15
# 11                Olive & 8th       2  0.689370        1        14
# 12            Grand & Olympic       1  0.436850        0        16
# 13             Figueroa & 8th       1  0.781118        1         8
# 14                 Hope & 6th       0  1.384666        3        14
# 15                 Main & 1st       6  4.168185        8        19
# 16             Hope & Olympic       1  0.280646        0        12
# 17             3rd & Santa Fe       2  0.524664        1         8
# 18             Broadway & 3rd       0  0.482691        0        16
# 19              1st & Central       6  0.324589        0         2
# 20    Figueroa & Cesar Chavez       3  0.292809        0        10
# 21    Factory Place & Alameda       0  0.323163        0        12
# 22                 Hope & 1st       0  0.125071        0         6
# 23                 Main & 5th       1  0.164649        0         6
# 24             Imperial & 7th       0  0.314015        0         9
# 25            3rd & San Pedro       1  0.394222        0        17
# 26                Grand & 3rd       2  0.631312        1         8
# 27   Industrial St & Mateo St       0  0.245897        0        11
# 28                 Main & 6th       2  0.180561        0         7
# 29          Wilshire & Witmer       2  0.264888        0        11
# 30       Willow St & Mateo St       0  0.246466        0         8
# 31               Grand & 14th       0  0.197987        0         5
# 32             Figueroa & 9th       0  0.589952        1        10
# 33               7th & Spring       3  0.403695        0         7
# 34                Hope & 11th       2  0.432381        0        10
# 35                Olive & 5th       0  0.953742        2        18
# 36                 8th & Wall       0  0.119285        0        12
# 37               5th & Hewitt       0  0.260761        0         9
# 38             2nd & Figueroa       2  0.938180        2        10
# 39       Los Angeles & Temple       0  0.818669        2        13
# 40  Union Station West Portal      12  1.473679        3         0
# 41            Figueroa & Pico       0  0.157723        0         9
# 42          9th & Los Angeles       0  0.286689        0        13
# 43                 Main & 9th       0  0.453661        0         9
# 44               Spring & 3rd       2  0.990235        2         6
# 45                12th & Hill       1  0.973827        2         9
# 46                 2nd & Hill       0  0.548926        1         9
# 47               11th & Maple       0  0.080159        0         8
# 48          Hill & Washington       0  0.228280        0        10
# 49         Grand & Washington       0  0.126993        0         9
# 50             Grand & Temple       0  0.446236        0         9
# 51             New High & Ord       0  0.072245        0        11
# 52            18th & Figueroa       0  0.024793        0         7
# 53           18th & San Pedro       0  0.093411        0         7
# 54            Stanford & 12th       0  0.571047        1        11
# 55             Hill & College       0  0.164530        0        17

# %%
# df = merge_live_pred_df.copy()
# df.to_csv('df_9_30_5pm.csv')

# %%
# !ls
# Out:
# Data                             end_station_pred_df.pickle
# LICENSE                          functions.py
# Live_station_status.ipynb        history
# README.md                        markers.html
# TimeSeries_BikeStation.ipynb     station_name.csv
# capstone_EDA.ipynb               station_name.json
# capstone_TimeSeries-Copy1.ipynb  station_pred_df.pickle
# capstone_TimeSeries.ipynb        station_pred_df1.pickle
# capstone_TimeSeries_hourly.ipynb

# %% [markdown]
# ## Create Folium Map that will display available bikes,  open docks, and forecasted available bikes in next hour for each bike stations.

# %%
def get_base_map(df):
    minimap = MiniMap(toggle_display=True, width=300, height=150, zoom_animation=True, zoom_level_offset=-6, position='topleft')
   
    return folium.Map(location=[df.latitude.mean(),
                             df.longitude.mean()],
                   zoom_start=20,
                     tiles='OpenStreetMap').add_child(minimap)
base = get_base_map(merge_live_pred_df)
base
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def add_station_markers(initial_map, df):
    #station location visualization
    
    out_map = initial_map
    for lat, lon, Name, Available, Opendocks, Next_hr_remaining, in zip(df['latitude'], df['longitude'], df['name'], 
                                df['bikesAvailable'], df['docksAvailable'], df['nextHour']):
        folium.Marker([lat,lon], popup=(str(Name).capitalize() + '<br>'
                                        '<br><b>Available: </b>' + str(Available) + '<br>'
                                        '<br><b>Opendocks: </b>' + str(Opendocks) + '<br>'
                                        '<br><b>Remaining Next Hour:</b> ' + str(Next_hr_remaining)),
                     icon=folium.Icon(color='green')).add_to(out_map)
    return out_map

markers = add_station_markers(base, merge_live_pred_df)
markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
markers.save('markers.html')

# %%
# !ls
# Out:
# Data                             capstone_TimeSeries.ipynb
# LICENSE                          capstone_TimeSeries_hourly.ipynb
# Live_station_status.ipynb        functions.py
# README.md                        markers.html
# TimeSeries_BikeStation.ipynb     station_pred_df.pickle
# capstone_EDA.ipynb               station_pred_df1.pickle
# capstone_TimeSeries-Copy1.ipynb

# %%
live_station_df.head()
# Out:
#                    ds  bikesAvailable  docksAvailable kioskId  latitude  \
# 0 2019-09-30 17:00:00              20               6    3005  34.04850
# 1 2019-09-30 17:00:00              18               5    3006  34.04554
# 2 2019-09-30 17:00:00               4              18    3007  34.05048
# 3 2019-09-30 17:00:00               5              10    3008  34.04661
# 4 2019-09-30 17:00:00               6              16    3010  34.03705
#
#    longitude            name                        id
# 0 -118.25854    7th & Flower  2019-09-30 17:00:00-3005
# 1 -118.25667     Olive & 8th  2019-09-30 17:00:00-3006
# 2 -118.25459     5th & Grand  2019-09-30 17:00:00-3007
# 3 -118.26273  Figueroa & 9th  2019-09-30 17:00:00-3008
# 4 -118.25487    11th & Maple  2019-09-30 17:00:00-3010

# %%
live_station_df.groupby('name')['latitude','longitude'].apply(lambda x: x.values.tolist()).to_dict()
# Out:
# {'11th & Maple': [[34.03705, -118.25487]],
#  '12th & Hill': [[34.03861, -118.26086]],
#  '12th & Valencia': [[34.04557, -118.27419]],
#  '17th St / SMC Expo Line Station': [[34.02338, -118.47964]],
#  '18th & Figueroa': [[34.03568, -118.27081]],
#  '18th & San Pedro': [[34.02851, -118.25667]],
#  '1st & Central': [[34.0493, -118.23881]],
#  '1st & Judge John Aiso': [[34.05091, -118.24097]],
#  '23rd St & Flower': [[34.03027, -118.27319]],
#  '25th & Vermont': [[34.03364, -118.29131]],
#  '28th & Figueroa': [[34.02629, -118.27769]],
#  '28th & University': [[34.02762, -118.28068]],
#  '29th & Ellendale': [[34.02835, -118.28867]],
#  '2nd & Figueroa': [[34.05697, -118.25359]],
#  '2nd & Hill': [[34.05287, -118.24749]],
#  '32nd & Figueroa': [[34.02371, -118.27917]],
#  '3rd & San Pedro': [[34.04775, -118.24317]],
#  '3rd & Santa Fe': [[34.04607, -118.23309]],
#  '4th & Vermont': [[34.06699, -118.29088]],
#  '5th & Grand': [[34.05048, -118.25459]],
#  '5th & Hewitt': [[34.04169, -118.23535]],
#  '7th & Berendo': [[34.05969, -118.29466]],
#  '7th & Bixel': [[34.0511, -118.26456]],
#  '7th & Broadway': [[34.04542, -118.25352]],
#  '7th & Flower': [[34.0485, -118.25854]],
#  '7th & Park View': [[34.05771, -118.27976]],
#  '7th & Spring': [[34.0447, -118.25244]],
#  '7th & Westminster': [[33.9953, -118.46484]],
#  '8th & Vermont': [[34.05765, -118.29218]],
#  '8th & Wall': [[34.03987, -118.25004]],
#  '9th & Los Angeles': [[34.0406, -118.25384]],
#  'Abbot Kinney & Cadiz': [[33.99116, -118.46829]],
#  'Albany & Olympic': [[34.04813, -118.27103]],
#  'Bagley & Venice': [[34.02569, -118.3953]],
#  "Banning's Landing": [[33.76666, -118.26102]],
#  'Barrington & National': [[34.02245, -118.43833]],
#  'Berendo & Olympic': [[34.0519, -118.29368]],
#  'Boylston & 3rd': [[34.05701, -118.2577]],
#  'Broadway & 3rd': [[34.05088, -118.24825]],
#  'Broadway & 9th': [[34.04211, -118.25619]],
#  'Cabrillo Beach': [[33.71098, -118.28467]],
#  'California & Lincoln': [[33.99832, -118.46098]],
#  'Catalina Express': [[33.74892, -118.27519]],
#  'Centinela & Lucile': [[33.98292, -118.41093]],
#  'Centre & 6th': [[33.73899, -118.28363]],
#  'Chandler & Cahuenga': [[34.16875, -118.36187]],
#  'Chandler & Colfax': [[34.16835, -118.3875]],
#  'Chandler & Laurel Canyon': [[34.16833, -118.39616]],
#  'Crafted 22nd St Park': [[33.72582, -118.28051]],
#  'DoubleTree Hotel': [[33.71926, -118.28272]],
#  'Downtown Harbor': [[33.73898, -118.27927]],
#  'Downtown Santa Monica Expo Line Station': [[34.01431, -118.49134]],
#  'Durango & Venice': [[34.02683, -118.39352]],
#  'Expo Park/LAFC': [[34.01252, -118.2859]],
#  'Expo/Sepulveda Expo Line Station': [[34.03535, -118.43414]],
#  'Factory Place & Alameda': [[34.03922, -118.23649]],
#  'Fanfare Fountain': [[33.74913, -118.28018]],
#  'Figueroa & 8th': [[34.0484, -118.26095]],
#  'Figueroa & 9th': [[34.04661, -118.26273]],
#  'Figueroa & Cesar Chavez': [[34.06318, -118.24588]],
#  'Figueroa & McCarthy Way': [[34.0203, -118.28118]],
#  'Figueroa & Pico': [[34.04113, -118.26798]],
#  'Flower & Jefferson': [[34.02166, -118.27869]],
#  'Franklin & Hillhurst': [[34.10536, -118.28727]],
#  'Grand & 14th': [[34.03746, -118.26538]],
#  'Grand & 3rd': [[34.0532, -118.25095]],
#  'Grand & 7th': [[34.04681, -118.25698]],
#  'Grand & Olympic': [[34.04373, -118.26014]],
#  'Grand & Temple': [[34.05832, -118.24609]],
#  'Grand & Washington': [[34.03286, -118.26808]],
#  'Grand / LATTC': [[34.0298, -118.27031]],
#  'Hill & College': [[34.06428, -118.23894]],
#  'Hill & Washington': [[34.03105, -118.26709]],
#  'Hillhurst & Kingswell': [[34.10233, -118.28746]],
#  'Hoover & 29th': [[34.02868, -118.28411]],
#  'Hoover & 32nd': [[34.02586, -118.2841]],
#  'Hoover & Fountain': [[34.09493, -118.28456]],
#  'Hope & 11th': [[34.04206, -118.26338]],
#  'Hope & 1st': [[34.05772, -118.24897]],
#  'Hope & 6th': [[34.04989, -118.25588]],
#  'Hope & Olympic': [[34.04417, -118.26117]],
#  'Imperial & 7th': [[34.0348, -118.23128]],
#  'Industrial St & Mateo St': [[34.0358, -118.23317]],
#  'Inglewood & Ballona': [[33.99032, -118.41205]],
#  'Inglewood & Braddock': [[33.99302, -118.41491]],
#  'James M. Wood & Alvarado': [[34.05323, -118.27842]],
#  'Kenmore & 3rd': [[34.06927, -118.29659]],
#  'Kenmore & 6th': [[34.06335, -118.2968]],
#  'Lankershim & Califa': [[34.17766, -118.38228]],
#  'Lankershim & Hesby': [[34.16171, -118.37282]],
#  'Lankershim & Moorpark': [[34.15069, -118.36613]],
#  'Lankershim & Vineland': [[34.15832, -118.37081]],
#  'Los Angeles & Temple': [[34.0529, -118.24156]],
#  'Lucile & Hoover': [[34.08265, -118.28439]],
#  'Magnolia & Cartwright': [[34.16495, -118.36363]],
#  'Magnolia & Clybourn': [[34.16522, -118.35515]],
#  'Main & 1st': [[34.05194, -118.24353]],
#  'Main & 4th': [[34.04885, -118.24642]],
#  'Main & 5th': [[34.04682, -118.24835]],
#  'Main & 6th': [[34.04518, -118.25024]],
#  'Main & 9th': [[34.04099, -118.2558]],
#  'Mar Vista Rec Center': [[34.01688, -118.42845]],
#  'Mariota & Riverside': [[34.152, -118.3506]],
#  'Maubert & Vermont': [[34.09905, -118.2915]],
#  'Maxella & Del Ray': [[33.98651, -118.44192]],
#  'McLaughlin & Venice': [[34.00902, -118.42501]],
#  'Melbourne & Vermont': [[34.10363, -118.29131]],
#  'National & Motor': [[34.02948, -118.41047]],
#  'New High & Ord': [[34.06056, -118.23833]],
#  'Newton & Central': [[34.02783, -118.24714]],
#  'Normandie & Hollywood': [[34.10189, -118.30061]],
#  'Normandie & Sunset': [[34.098, -118.30047]],
#  'North Hollywood Station ': [[34.16863, -118.37707]],
#  'Ocean Front Walk & Navy': [[33.99556, -118.48155]],
#  'Ocean Front Walk & North Venice': [[33.98434, -118.47155]],
#  'Olive & 5th': [[34.04804, -118.25374]],
#  'Olive & 8th': [[34.04554, -118.25667]],
#  'Pacific & North Venice': [[33.98493, -118.46996]],
#  'Palms & Kelton': [[34.02233, -118.41577]],
#  'Palms & Motor': [[34.02655, -118.40846]],
#  'Palms & National': [[34.02912, -118.40317]],
#  'Park & Echo Park': [[34.07483, -118.25873]],
#  'Pico & Flower': [[34.03998, -118.2664]],
#  "Ports O'Call": [[33.73352, -118.27779]],
#  'Public Bike Rack: Culver City Expo Line': [[34.02788, -118.3889]],
#  'Public Bike Rack: Universal City/Studio City Red Line Station': [[34.13957,
#    -118.36225]],
#  'Public Bike Rack: Westwood/Rancho Park Expo Line': [[34.03668, -118.42534]],
#  'Rampart & Wilshire': [[34.0616, -118.28199]],
#  'Riverside & Cahuenga': [[34.15214, -118.36195]],
#  'Riverside & Colfax': [[34.15758, -118.38826]],
#  'Rose & 7th': [[34.00088, -118.46891]],
#  'Rose & Main': [[33.99624, -118.47745]],
#  'Rose & Rennie': [[33.9986, -118.47298]],
#  'Row DTLA': [[34.03352, -118.24184]],
#  'Santa Monica & Virgil': [[34.09097, -118.28625]],
#  'Sepulveda & Charnock': [[34.01737, -118.4206]],
#  'Sepulveda & Lucerne': [[34.00033, -118.40232]],
#  'Sepulveda & National': [[34.02697, -118.42821]],
#  'Sepulveda & Palms': [[34.02006, -118.42268]],
#  'Sepulveda & Venice': [[34.01376, -118.4178]],
#  'Severance & Adams': [[34.03017, -118.28095]],
#  'Shatto Pl & Wilshire': [[34.06258, -118.29009]],
#  'Spring & 3rd': [[34.04998, -118.24716]],
#  'Spring & College': [[34.06339, -118.23616]],
#  'Stanford & 12th': [[34.03189, -118.25018]],
#  'Sunset & Douglas': [[34.07364, -118.25157]],
#  'Sunset & Virgil': [[34.09801, -118.28707]],
#  'Temple & Vignes': [[34.05014, -118.23319]],
#  'Traction & Rose': [[34.04652, -118.23741]],
#  'Tujunga & Moorpark': [[34.14987, -118.37889]],
#  'USS IOWA': [[33.74136, -118.27807]],
#  'Union & 7th': [[34.05403, -118.27092]],
#  'Union & Olympic': [[34.04887, -118.2743]],
#  'Union Station West Portal': [[34.05661, -118.23721]],
#  'University & 30th': [[34.02662, -118.28181]],
#  'University & Hoover': [[34.02404, -118.28341]],
#  'Venice & Beethoven': [[33.99958, -118.44136]],
#  'Venice & Clarington': [[34.02252, -118.40059]],
#  'Venice & Colonial': [[34.00351, -118.43438]],
#  'Venice & Glendon': [[34.01768, -118.40908]],
#  'Venice & Hughes': [[34.02339, -118.39922]],
#  'Venice & Inglewood': [[34.00587, -118.42916]],
#  'Venice & Lincoln': [[33.99373, -118.45356]],
#  'Venice & Motor': [[34.02018, -118.40403]],
#  'Venice & Sawtelle': [[34.0118, -118.41953]],
#  'Venice & Walgrove': [[33.99723, -118.44597]],
#  'Vermont & Beverly': [[34.07561, -118.29186]],
#  'Vermont & Franklin': [[34.10578, -118.29194]],
#  'Vermont Pl & Vermont ': [[34.09249, -118.29144]],
#  'Vineland & Burbank': [[34.17245, -118.37037]],
#  'Vineland & Otsego': [[34.16289, -118.37016]],
#  'Washington & Abbot Kinney': [[33.98842, -118.45163]],
#  'Waterfront Park (East)': [[33.7723, -118.26804]],
#  'Waterfront Park (West)': [[33.77176, -118.27654]],
#  'Westlake & 3rd': [[34.06228, -118.27152]],
#  'Westlake/Macarthur Park Station': [[34.05681, -118.275]],
#  'Westlawn & Beatrice': [[33.98079, -118.4149]],
#  'Westwood & National': [[34.03047, -118.42098]],
#  'Willow St & Mateo St': [[34.03919, -118.23253]],
#  'Wilshire & Alexandria': [[34.06166, -118.29824]],
#  'Wilshire & Hobart': [[34.06162, -118.30557]],
#  'Wilshire & Witmer': [[34.05357, -118.26636]],
#  'Windward & Main': [[33.98813, -118.47174]]}

# %%
d = {}
for i in df['name'].unique():
    d[i] = [{live_station_df['name'][j]: (live_station_df['latitude'][j], live_station_df['longitude'][j])} for j in 
            live_station_df[live_station_df['name']==i].index]

# %%
d
# Out:
# {'Pico & Flower': [{'Pico & Flower': (34.03998, -118.2664)}],
#  '7th & Flower': [{'7th & Flower': (34.0485, -118.25854)}],
#  '1st & Judge John Aiso': [{'1st & Judge John Aiso': (34.05091, -118.24097)}],
#  '7th & Broadway': [{'7th & Broadway': (34.04542, -118.25352)}],
#  '5th & Grand': [{'5th & Grand': (34.05048, -118.25459)}],
#  'Broadway & 9th': [{'Broadway & 9th': (34.04211, -118.25619)}],
#  'Spring & College': [{'Spring & College': (34.06339, -118.23616)}],
#  'Traction & Rose': [{'Traction & Rose': (34.04652, -118.23741)}],
#  'Grand & 7th': [{'Grand & 7th': (34.04681, -118.25698)}],
#  '7th & Bixel': [{'7th & Bixel': (34.0511, -118.26456)}],
#  'Main & 4th': [{'Main & 4th': (34.04885, -118.24642)}],
#  'Olive & 8th': [{'Olive & 8th': (34.04554, -118.25667)}],
#  'Grand & Olympic': [{'Grand & Olympic': (34.04373, -118.26014)}],
#  'Figueroa & 8th': [{'Figueroa & 8th': (34.0484, -118.26095)}],
#  'Hope & 6th': [{'Hope & 6th': (34.04989, -118.25588)}],
#  'Main & 1st': [{'Main & 1st': (34.05194, -118.24353)}],
#  'Hope & Olympic': [{'Hope & Olympic': (34.04417, -118.26117)}],
#  '3rd & Santa Fe': [{'3rd & Santa Fe': (34.04607, -118.23309)}],
#  'Broadway & 3rd': [{'Broadway & 3rd': (34.05088, -118.24825)}],
#  '1st & Central': [{'1st & Central': (34.0493, -118.23881)}],
#  'Figueroa & Cesar Chavez': [{'Figueroa & Cesar Chavez': (34.06318,
#     -118.24588)}],
#  'Factory Place & Alameda': [{'Factory Place & Alameda': (34.03922,
#     -118.23649)}],
#  'Hope & 1st': [{'Hope & 1st': (34.05772, -118.24897)}],
#  'Main & 5th': [{'Main & 5th': (34.04682, -118.24835)}],
#  'Imperial & 7th': [{'Imperial & 7th': (34.0348, -118.23128)}],
#  '3rd & San Pedro': [{'3rd & San Pedro': (34.04775, -118.24317)}],
#  'Grand & 3rd': [{'Grand & 3rd': (34.0532, -118.25095)}],
#  'Industrial St & Mateo St': [{'Industrial St & Mateo St': (34.0358,
#     -118.23317)}],
#  'Main & 6th': [{'Main & 6th': (34.04518, -118.25024)}],
#  'Wilshire & Witmer': [{'Wilshire & Witmer': (34.05357, -118.26636)}],
#  'Willow St & Mateo St': [{'Willow St & Mateo St': (34.03919, -118.23253)}],
#  'Grand & 14th': [{'Grand & 14th': (34.03746, -118.26538)}],
#  'Figueroa & 9th': [{'Figueroa & 9th': (34.04661, -118.26273)}],
#  '7th & Spring': [{'7th & Spring': (34.0447, -118.25244)}],
#  'Hope & 11th': [{'Hope & 11th': (34.04206, -118.26338)}],
#  'Olive & 5th': [{'Olive & 5th': (34.04804, -118.25374)}],
#  '8th & Wall': [{'8th & Wall': (34.03987, -118.25004)}],
#  '5th & Hewitt': [{'5th & Hewitt': (34.04169, -118.23535)}],
#  '2nd & Figueroa': [{'2nd & Figueroa': (34.05697, -118.25359)}],
#  'Los Angeles & Temple': [{'Los Angeles & Temple': (34.0529, -118.24156)}],
#  'Union Station West Portal': [{'Union Station West Portal': (34.05661,
#     -118.23721)}],
#  'Figueroa & Pico': [{'Figueroa & Pico': (34.04113, -118.26798)}],
#  '9th & Los Angeles': [{'9th & Los Angeles': (34.0406, -118.25384)}],
#  'Main & 9th': [{'Main & 9th': (34.04099, -118.2558)}],
#  'Spring & 3rd': [{'Spring & 3rd': (34.04998, -118.24716)}],
#  '12th & Hill': [{'12th & Hill': (34.03861, -118.26086)}],
#  '2nd & Hill': [{'2nd & Hill': (34.05287, -118.24749)}],
#  '11th & Maple': [{'11th & Maple': (34.03705, -118.25487)}],
#  'Hill & Washington': [{'Hill & Washington': (34.03105, -118.26709)}],
#  'Grand & Washington': [{'Grand & Washington': (34.03286, -118.26808)}],
#  'Grand & Temple': [{'Grand & Temple': (34.05832, -118.24609)}],
#  'New High & Ord': [{'New High & Ord': (34.06056, -118.23833)}],
#  '18th & Figueroa': [{'18th & Figueroa': (34.03568, -118.27081)}],
#  '18th & San Pedro': [{'18th & San Pedro': (34.02851, -118.25667)}],
#  'Stanford & 12th': [{'Stanford & 12th': (34.03189, -118.25018)}],
#  'Hill & College': [{'Hill & College': (34.06428, -118.23894)}]}

# %%
station_name_df = merge_live_pred_df[['station', 'name', 'latitude', 'longitude']]
station_name_df.shape
# Out:
# (56, 4)

# %%
station_name_df.head()
# Out:
#   station                   name  latitude  longitude
# 0    3047          Pico & Flower  34.03998 -118.26640
# 1    3005           7th & Flower  34.04850 -118.25854
# 2    3023  1st & Judge John Aiso  34.05091 -118.24097
# 3    3051         7th & Broadway  34.04542 -118.25352
# 4    3007            5th & Grand  34.05048 -118.25459

# %%
station_name_df.to_csv("station_name.csv")

# %%
import csv

with open('station_name.csv') as csvfile:
        reader = csv.DictReader(csvfile)
        stations = {}
        for row in reader:
            kiosk_id= row['station']
            lat = row['latitude']
            lng = row['longitude']
            stations[kiosk_id] = (lat, lng)

# %%
import json

with open('station_name.json', 'w') as outfile:
    json.dump(stations, outfile)

# %%
# !ls
# Out:
# Data                             df.csv
# LICENSE                          df_9_26_6pm.csv
# Live_station_status.ipynb        df_9_30_5pm.csv
# README.md                        functions.py
# TimeSeries_BikeStation.ipynb     markers.html
# capstone_EDA.ipynb               station_name.csv
# capstone_TimeSeries-Copy1.ipynb  station_name.json
# capstone_TimeSeries.ipynb        station_pred_df.pickle
# capstone_TimeSeries_hourly.ipynb station_pred_df1.pickle

# %%
# station_name_df.to_csv("station_name.csv")

# %%
# # data = request.form
# # print(data)

# # station = data["station"]

# stations = station_name_df

# for lat, lng = (stations['latitude'][0], stations['longitude'][0])

# %%
test = merge_live_pred_df[['station', 'name', 'latitude', 'longitude']]
test.shape
# Out:
# (56, 4)
