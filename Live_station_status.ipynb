# %%
import requests
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import folium
from time import time
import pickle

# %%
def get_live_station(url):
    
    response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    stations = response.json()
    
    output = []
    
    for station in stations['features']:
        dict_keys = ['kioskId', 'bikesAvailable', 'docksAvailable', 'name', 'latitude', 'longitude']
        data = {k : station['properties'][k] for k in dict_keys}
        data['time'] = time()
        output.append(data)

    return pd.DataFrame(output)

# %%
live_station_df = get_live_station("https://bikeshare.metro.net/stations/json/")
live_station_df.head()
# Out:
#    bikesAvailable  docksAvailable  kioskId  latitude  longitude  \
# 0              16              10     3005  34.04850 -118.25854
# 1              10              14     3006  34.04554 -118.25667
# 2               8              15     3007  34.05048 -118.25459
# 3               7               8     3008  34.04661 -118.26273
# 4               5              17     3010  34.03705 -118.25487
#
#              name          time
# 0    7th & Flower  1.569524e+09
# 1     Olive & 8th  1.569524e+09
# 2     5th & Grand  1.569524e+09
# 3  Figueroa & 9th  1.569524e+09
# 4    11th & Maple  1.569524e+09

# %%
# change time featur into str and take first 10 character.
live_station_df.time = live_station_df.time.astype(str)
live_station_df.time = live_station_df.time.str[:10]

# %%
# convert unix timestamp to Y/M/D %H/%M/%S format
live_station_df['time'] = pd.to_datetime(live_station_df['time'], unit='s')

# %%
# change name of time feature to ds and set it to index
# replace minutes and seconds to 0 
live_station_df.rename(columns={'time':'ds'}, inplace=True)
live_station_df.set_index('ds', inplace=True)
live_station_df.index = live_station_df.index.map(lambda x: x.replace(second=0))
live_station_df.index = live_station_df.index.map(lambda x: x.replace(minute=0))

# %%
live_station_df.kioskId = live_station_df.kioskId.astype(str)

# %%
live_station_df.head()
# Out:
#                      bikesAvailable  docksAvailable kioskId  latitude  \
# ds
# 2019-09-26 18:00:00              16              10    3005  34.04850
# 2019-09-26 18:00:00              10              14    3006  34.04554
# 2019-09-26 18:00:00               8              15    3007  34.05048
# 2019-09-26 18:00:00               7               8    3008  34.04661
# 2019-09-26 18:00:00               5              17    3010  34.03705
#
#                      longitude            name
# ds
# 2019-09-26 18:00:00 -118.25854    7th & Flower
# 2019-09-26 18:00:00 -118.25667     Olive & 8th
# 2019-09-26 18:00:00 -118.25459     5th & Grand
# 2019-09-26 18:00:00 -118.26273  Figueroa & 9th
# 2019-09-26 18:00:00 -118.25487    11th & Maple

# %% [markdown]
# ### Create new column concatenated with ds and kioskid to merge it with station_pred_df1

# %%
live_station_df.reset_index(inplace=True)

# %%
live_station_df['id'] = live_station_df.ds.astype(str) + '-' + live_station_df.kioskId
live_station_df.head()
# Out:
#                    ds  bikesAvailable  docksAvailable kioskId  latitude  \
# 0 2019-09-26 18:00:00              16              10    3005  34.04850
# 1 2019-09-26 18:00:00              10              14    3006  34.04554
# 2 2019-09-26 18:00:00               8              15    3007  34.05048
# 3 2019-09-26 18:00:00               7               8    3008  34.04661
# 4 2019-09-26 18:00:00               5              17    3010  34.03705
#
#    longitude            name                        id
# 0 -118.25854    7th & Flower  2019-09-26 18:00:00-3005
# 1 -118.25667     Olive & 8th  2019-09-26 18:00:00-3006
# 2 -118.25459     5th & Grand  2019-09-26 18:00:00-3007
# 3 -118.26273  Figueroa & 9th  2019-09-26 18:00:00-3008
# 4 -118.25487    11th & Maple  2019-09-26 18:00:00-3010

# %% [markdown]
# ## Read forecast station df stores as in pickle

# %%
with open('station_pred_df1.pickle', 'rb') as f:
    station_pred_df1 = pickle.load(f)

station_pred_df1.head()
# Out:
#   station                  ds     y_hat
# 0  3047.0 2019-09-24 13:00:00  0.439309
# 1  3047.0 2019-09-24 14:00:00  0.432759
# 2  3047.0 2019-09-24 15:00:00  0.434784
# 3  3047.0 2019-09-24 16:00:00  0.498354
# 4  3047.0 2019-09-24 17:00:00  0.608555

# %%
station_pred_df1.tail()
# Out:
#                     station     y_hat                        id
# ds
# 2019-10-06 18:00:00    3078  0.408277  2019-10-06 18:00:00-3078
# 2019-10-06 19:00:00    3078  0.371387  2019-10-06 19:00:00-3078
# 2019-10-06 20:00:00    3078  0.326630  2019-10-06 20:00:00-3078
# 2019-10-06 21:00:00    3078  0.282961  2019-10-06 21:00:00-3078
# 2019-10-06 22:00:00    3078  0.251276  2019-10-06 22:00:00-3078

# %%
# Take first 4 character in station feature
station_pred_df1.station = station_pred_df1.station.str[:4]

# %%
station_pred_df1['id'] = station_pred_df1.ds.astype(str) + '-' + station_pred_df1.station

# %%
station_pred_df1.tail()
# Out:
#       station                  ds     y_hat                        id
# 17995    3078 2019-10-06 18:00:00  0.408277  2019-10-06 18:00:00-3078
# 17996    3078 2019-10-06 19:00:00  0.371387  2019-10-06 19:00:00-3078
# 17997    3078 2019-10-06 20:00:00  0.326630  2019-10-06 20:00:00-3078
# 17998    3078 2019-10-06 21:00:00  0.282961  2019-10-06 21:00:00-3078
# 17999    3078 2019-10-06 22:00:00  0.251276  2019-10-06 22:00:00-3078

# %%
station_pred_df1.set_index('ds', inplace=True)

# %%
merge_live_pred_df = station_pred_df1.merge(live_station_df, on='id')
merge_live_pred_df.head()
# Out:
#   station     y_hat                        id                  ds  \
# 0    3047  0.681051  2019-09-26 18:00:00-3047 2019-09-26 18:00:00
# 1    3005  4.124923  2019-09-26 18:00:00-3005 2019-09-26 18:00:00
# 2    3023  0.586036  2019-09-26 18:00:00-3023 2019-09-26 18:00:00
# 3    3051  0.659422  2019-09-26 18:00:00-3051 2019-09-26 18:00:00
# 4    3007  1.657867  2019-09-26 18:00:00-3007 2019-09-26 18:00:00
#
#    bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0              14              22    3047  34.03998 -118.26640
# 1              16              10    3005  34.04850 -118.25854
# 2              10              12    3023  34.05091 -118.24097
# 3               6              10    3051  34.04542 -118.25352
# 4               8              15    3007  34.05048 -118.25459
#
#                     name
# 0          Pico & Flower
# 1           7th & Flower
# 2  1st & Judge John Aiso
# 3         7th & Broadway
# 4            5th & Grand

# %%
merge_live_pred_df.head()
# Out:
#   station     y_hat                        id                  ds  \
# 0    3047  0.681051  2019-09-26 18:00:00-3047 2019-09-26 18:00:00
# 1    3005  4.124923  2019-09-26 18:00:00-3005 2019-09-26 18:00:00
# 2    3023  0.586036  2019-09-26 18:00:00-3023 2019-09-26 18:00:00
# 3    3051  0.659422  2019-09-26 18:00:00-3051 2019-09-26 18:00:00
# 4    3007  1.657867  2019-09-26 18:00:00-3007 2019-09-26 18:00:00
#
#    bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0              14              22    3047  34.03998 -118.26640
# 1              16              10    3005  34.04850 -118.25854
# 2              10              12    3023  34.05091 -118.24097
# 3               6              10    3051  34.04542 -118.25352
# 4               8              15    3007  34.05048 -118.25459
#
#                     name
# 0          Pico & Flower
# 1           7th & Flower
# 2  1st & Judge John Aiso
# 3         7th & Broadway
# 4            5th & Grand

# %%
def normalize_demand_number(record):
    if record['y_hat'] >= 4.5:
        return round(record['y_hat']) * 2.5
    elif record['y_hat'] >= 4:
        return round(record['y_hat']) * 2
    elif record['y_hat'] >= 3:
        return round(record['y_hat']) * 2
    elif record['y_hat'] >= 1:
        return round(record['y_hat']) * 3
    elif record['y_hat'] >= 0.7:
        return round(record['y_hat']) * 2
    elif record['y_hat'] >= 0.4:
        return round(record['y_hat']) * 1
    else:
        return 0

# %%
merge_live_pred_df['demand'] = merge_live_pred_df.apply(normalize_demand_number, axis=1)
merge_live_pred_df
# Out:
#    station     y_hat                        id                  ds  \
# 0     3047  0.681051  2019-09-26 18:00:00-3047 2019-09-26 18:00:00
# 1     3005  4.124923  2019-09-26 18:00:00-3005 2019-09-26 18:00:00
# 2     3023  0.586036  2019-09-26 18:00:00-3023 2019-09-26 18:00:00
# 3     3051  0.659422  2019-09-26 18:00:00-3051 2019-09-26 18:00:00
# 4     3007  1.657867  2019-09-26 18:00:00-3007 2019-09-26 18:00:00
# 5     3075  0.829424  2019-09-26 18:00:00-3075 2019-09-26 18:00:00
# 6     3066  0.587705  2019-09-26 18:00:00-3066 2019-09-26 18:00:00
# 7     3082  0.982937  2019-09-26 18:00:00-3082 2019-09-26 18:00:00
# 8     3064  1.316154  2019-09-26 18:00:00-3064 2019-09-26 18:00:00
# 9     3052  0.652791  2019-09-26 18:00:00-3052 2019-09-26 18:00:00
# 10    3029  0.657555  2019-09-26 18:00:00-3029 2019-09-26 18:00:00
# 11    3006  1.489873  2019-09-26 18:00:00-3006 2019-09-26 18:00:00
# 12    3018  0.686545  2019-09-26 18:00:00-3018 2019-09-26 18:00:00
# 13    3035  1.287873  2019-09-26 18:00:00-3035 2019-09-26 18:00:00
# 14    3032  1.368709  2019-09-26 18:00:00-3032 2019-09-26 18:00:00
# 15    3030  3.155211  2019-09-26 18:00:00-3030 2019-09-26 18:00:00
# 16    3074  1.181373  2019-09-26 18:00:00-3074 2019-09-26 18:00:00
# 17    3022  1.005092  2019-09-26 18:00:00-3022 2019-09-26 18:00:00
# 18    3069  0.909319  2019-09-26 18:00:00-3069 2019-09-26 18:00:00
# 19    3042  0.872220  2019-09-26 18:00:00-3042 2019-09-26 18:00:00
# 20    3026  0.681336  2019-09-26 18:00:00-3026 2019-09-26 18:00:00
# 21    3054  0.549796  2019-09-26 18:00:00-3054 2019-09-26 18:00:00
# 22    3024  0.408194  2019-09-26 18:00:00-3024 2019-09-26 18:00:00
# 23    3038  0.955340  2019-09-26 18:00:00-3038 2019-09-26 18:00:00
# 24    3037  0.416920  2019-09-26 18:00:00-3037 2019-09-26 18:00:00
# 25    3062  0.700774  2019-09-26 18:00:00-3062 2019-09-26 18:00:00
# 26    3068  2.009940  2019-09-26 18:00:00-3068 2019-09-26 18:00:00
# 27    3058  0.412813  2019-09-26 18:00:00-3058 2019-09-26 18:00:00
# 28    3067  0.897061  2019-09-26 18:00:00-3067 2019-09-26 18:00:00
# 29    3040  0.566657  2019-09-26 18:00:00-3040 2019-09-26 18:00:00
# 30    3036  0.282834  2019-09-26 18:00:00-3036 2019-09-26 18:00:00
# 31    3056  0.234791  2019-09-26 18:00:00-3056 2019-09-26 18:00:00
# 32    3008  0.853881  2019-09-26 18:00:00-3008 2019-09-26 18:00:00
# 33    3031  1.127662  2019-09-26 18:00:00-3031 2019-09-26 18:00:00
# 34    3034  0.764400  2019-09-26 18:00:00-3034 2019-09-26 18:00:00
# 35    3063  1.091713  2019-09-26 18:00:00-3063 2019-09-26 18:00:00
# 36    3077  0.181320  2019-09-26 18:00:00-3077 2019-09-26 18:00:00
# 37    3048  0.558331  2019-09-26 18:00:00-3048 2019-09-26 18:00:00
# 38    3049  1.108030  2019-09-26 18:00:00-3049 2019-09-26 18:00:00
# 39    3016  0.918862  2019-09-26 18:00:00-3016 2019-09-26 18:00:00
# 40    3014  1.803353  2019-09-26 18:00:00-3014 2019-09-26 18:00:00
# 41    3011  0.253206  2019-09-26 18:00:00-3011 2019-09-26 18:00:00
# 42    3076  0.492082  2019-09-26 18:00:00-3076 2019-09-26 18:00:00
# 43    3033  0.679736  2019-09-26 18:00:00-3033 2019-09-26 18:00:00
# 44    3027  1.216132  2019-09-26 18:00:00-3027 2019-09-26 18:00:00
# 45    3019  1.109533  2019-09-26 18:00:00-3019 2019-09-26 18:00:00
# 46    3046  0.581508  2019-09-26 18:00:00-3046 2019-09-26 18:00:00
# 47    3010  0.139532  2019-09-26 18:00:00-3010 2019-09-26 18:00:00
# 48    3020  0.189336  2019-09-26 18:00:00-3020 2019-09-26 18:00:00
# 49    3025  0.094019  2019-09-26 18:00:00-3025 2019-09-26 18:00:00
# 50    3028  0.866572  2019-09-26 18:00:00-3028 2019-09-26 18:00:00
# 51    3065  0.304376  2019-09-26 18:00:00-3065 2019-09-26 18:00:00
# 52    3057  0.233812  2019-09-26 18:00:00-3057 2019-09-26 18:00:00
# 53    3045  0.110903  2019-09-26 18:00:00-3045 2019-09-26 18:00:00
# 54    3081  0.504231  2019-09-26 18:00:00-3081 2019-09-26 18:00:00
# 55    3078  0.285010  2019-09-26 18:00:00-3078 2019-09-26 18:00:00
#
#     bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0               14              22    3047  34.03998 -118.26640
# 1               16              10    3005  34.04850 -118.25854
# 2               10              12    3023  34.05091 -118.24097
# 3                6              10    3051  34.04542 -118.25352
# 4                8              15    3007  34.05048 -118.25459
# 5               10               6    3075  34.04211 -118.25619
# 6                4              23    3066  34.06339 -118.23616
# 7                5              20    3082  34.04652 -118.23741
# 8               12               6    3064  34.04681 -118.25698
# 9               15              19    3052  34.05110 -118.26456
# 10               7              17    3029  34.04885 -118.24642
# 11              10              14    3006  34.04554 -118.25667
# 12              10              11    3018  34.04373 -118.26014
# 13              19               4    3035  34.04840 -118.26095
# 14              17              14    3032  34.04989 -118.25588
# 15              16              12    3030  34.05194 -118.24353
# 16              11              11    3074  34.04417 -118.26117
# 17               0              26    3022  34.04607 -118.23309
# 18               9              14    3069  34.05088 -118.24825
# 19               7              11    3042  34.04930 -118.23881
# 20              12              13    3026  34.06318 -118.24588
# 21              13               6    3054  34.03922 -118.23649
# 22               5              12    3024  34.05772 -118.24897
# 23               7              11    3038  34.04682 -118.24835
# 24              10               8    3037  34.03480 -118.23128
# 25              13              12    3062  34.04775 -118.24317
# 26               7              18    3068  34.05320 -118.25095
# 27               7              21    3058  34.03580 -118.23317
# 28               9              10    3067  34.04518 -118.25024
# 29               6              22    3040  34.05357 -118.26636
# 30              12               5    3036  34.03919 -118.23253
# 31               9              11    3056  34.03746 -118.26538
# 32               7               8    3008  34.04661 -118.26273
# 33              17               7    3031  34.04470 -118.25244
# 34               6              23    3034  34.04206 -118.26338
# 35               8              13    3063  34.04804 -118.25374
# 36              10              11    3077  34.03987 -118.25004
# 37               4              12    3048  34.04169 -118.23535
# 38              13              19    3049  34.05697 -118.25359
# 39              21               9    3016  34.05290 -118.24156
# 40               6              23    3014  34.05661 -118.23721
# 41               3              16    3011  34.04113 -118.26798
# 42              19               9    3076  34.04060 -118.25384
# 43              11              10    3033  34.04099 -118.25580
# 44               7              20    3027  34.04998 -118.24716
# 45              16               3    3019  34.03861 -118.26086
# 46               3              14    3046  34.05287 -118.24749
# 47               5              17    3010  34.03705 -118.25487
# 48               8              13    3020  34.03105 -118.26709
# 49               9              12    3025  34.03286 -118.26808
# 50              14              10    3028  34.05832 -118.24609
# 51              20               3    3065  34.06056 -118.23833
# 52               9              11    3057  34.03568 -118.27081
# 53               7               7    3045  34.02851 -118.25667
# 54               9              10    3081  34.03189 -118.25018
# 55              15              18    3078  34.06428 -118.23894
#
#                          name  demand
# 0               Pico & Flower       1
# 1                7th & Flower       8
# 2       1st & Judge John Aiso       1
# 3              7th & Broadway       1
# 4                 5th & Grand       6
# 5              Broadway & 9th       2
# 6            Spring & College       1
# 7             Traction & Rose       2
# 8                 Grand & 7th       3
# 9                 7th & Bixel       1
# 10                 Main & 4th       1
# 11                Olive & 8th       3
# 12            Grand & Olympic       1
# 13             Figueroa & 8th       3
# 14                 Hope & 6th       3
# 15                 Main & 1st       6
# 16             Hope & Olympic       3
# 17             3rd & Santa Fe       3
# 18             Broadway & 3rd       2
# 19              1st & Central       2
# 20    Figueroa & Cesar Chavez       1
# 21    Factory Place & Alameda       1
# 22                 Hope & 1st       0
# 23                 Main & 5th       2
# 24             Imperial & 7th       0
# 25            3rd & San Pedro       2
# 26                Grand & 3rd       6
# 27   Industrial St & Mateo St       0
# 28                 Main & 6th       2
# 29          Wilshire & Witmer       1
# 30       Willow St & Mateo St       0
# 31               Grand & 14th       0
# 32             Figueroa & 9th       2
# 33               7th & Spring       3
# 34                Hope & 11th       2
# 35                Olive & 5th       3
# 36                 8th & Wall       0
# 37               5th & Hewitt       1
# 38             2nd & Figueroa       3
# 39       Los Angeles & Temple       2
# 40  Union Station West Portal       6
# 41            Figueroa & Pico       0
# 42          9th & Los Angeles       0
# 43                 Main & 9th       1
# 44               Spring & 3rd       3
# 45                12th & Hill       3
# 46                 2nd & Hill       1
# 47               11th & Maple       0
# 48          Hill & Washington       0
# 49         Grand & Washington       0
# 50             Grand & Temple       2
# 51             New High & Ord       0
# 52            18th & Figueroa       0
# 53           18th & San Pedro       0
# 54            Stanford & 12th       1
# 55             Hill & College       0

# %%
def nexthour(record):
    if record['bikesAvailable'] - record['demand'] >= 0:
        return record['bikesAvailable'] - record['demand']
    else:
        return 0

# %%
merge_live_pred_df['nextHour'] = merge_live_pred_df.apply(nexthour, axis=1)
merge_live_pred_df.head()
# Out:
#   station     y_hat                        id                  ds  \
# 0    3047  0.681051  2019-09-26 18:00:00-3047 2019-09-26 18:00:00
# 1    3005  4.124923  2019-09-26 18:00:00-3005 2019-09-26 18:00:00
# 2    3023  0.586036  2019-09-26 18:00:00-3023 2019-09-26 18:00:00
# 3    3051  0.659422  2019-09-26 18:00:00-3051 2019-09-26 18:00:00
# 4    3007  1.657867  2019-09-26 18:00:00-3007 2019-09-26 18:00:00
#
#    bikesAvailable  docksAvailable kioskId  latitude  longitude  \
# 0              14              22    3047  34.03998 -118.26640
# 1              16              10    3005  34.04850 -118.25854
# 2              10              12    3023  34.05091 -118.24097
# 3               6              10    3051  34.04542 -118.25352
# 4               8              15    3007  34.05048 -118.25459
#
#                     name  demand  nextHour
# 0          Pico & Flower       1        13
# 1           7th & Flower       8         8
# 2  1st & Judge John Aiso       1         9
# 3         7th & Broadway       1         5
# 4            5th & Grand       6         2

# %%
merge_live_pred_df.station.unique()
# Out:
# array(['3047', '3005', '3023', '3051', '3007', '3075', '3066', '3082',
#        '3064', '3052', '3029', '3006', '3018', '3035', '3032', '3030',
#        '3074', '3022', '3069', '3042', '3026', '3054', '3024', '3038',
#        '3037', '3062', '3068', '3058', '3067', '3040', '3036', '3056',
#        '3008', '3031', '3034', '3063', '3077', '3048', '3049', '3016',
#        '3014', '3011', '3076', '3033', '3027', '3019', '3046', '3010',
#        '3020', '3025', '3028', '3065', '3057', '3045', '3081', '3078'],
#       dtype=object)

# %%
df = merge_live_pred_df.copy()
df.to_csv('df.csv')

# %%
def get_base_map(df):
    return folium.Map(location=[df.latitude.mean(),
                             df.longitude.mean()],
                   zoom_start=14,
                     tiles='OpenStreetMap')
base = get_base_map(merge_live_pred_df)
base
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def add_station_markers(initial_map, df):
    #station location visualization
    
    out_map = initial_map
    for lat, lon, Name, Available, Opendocks, Next_hr_remaining, in zip(df['latitude'], df['longitude'], df['name'], 
                                df['bikesAvailable'], df['docksAvailable'], df['nextHour']):
        folium.Marker([lat,lon], popup=(str(Name).capitalize() + '<br>'
                                        '<br><b>Available: </b>' + str(Available) + '<br>'
                                        '<br><b>Opendocks: </b>' + str(Opendocks) + '<br>'
                                        '<br><b>Remaining Next Hour:</b> ' + str(Next_hr_remaining)),
                     icon=folium.Icon(color='green')).add_to(out_map)
    return out_map

markers = add_station_markers(base, merge_live_pred_df)
markers
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
markers.save('markers.html')

# %%
# !ls
# Out:
# Data                             capstone_TimeSeries.ipynb
# LICENSE                          capstone_TimeSeries_hourly.ipynb
# Live_station_status.ipynb        functions.py
# README.md                        markers.html
# TimeSeries_BikeStation.ipynb     station_pred_df.pickle
# capstone_EDA.ipynb               station_pred_df1.pickle
# capstone_TimeSeries-Copy1.ipynb

# %%
# !pwd
# Out:
# /Users/flatiron/Flatiron/capstone_project/Bber
